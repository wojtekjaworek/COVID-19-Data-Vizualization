# %% [markdown]
# # COVID-19 Data Visualization

# %% [markdown]
# ### Using Pandas, Matplotlib.pyplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# %% [markdown]
# #### specify data url, select country

# %%
data_url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'
country = 'China'

# %% [markdown]
# ### Read and clean data

# %%
data = pd.read_csv(data_url, delimiter=',', header=0, quotechar='"', encoding="utf8", parse_dates=['date'])
data.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 60 columns]

# %%
countries = data[['location']]
countries = countries.drop_duplicates(subset = ['location'], keep='first')

# %%
data = data[data['location'] == country]
data.head()
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 18335      CHN      Asia    China 2020-01-22        548.0        NaN
# 18336      CHN      Asia    China 2020-01-23        641.0       93.0
# 18337      CHN      Asia    China 2020-01-24        918.0      277.0
# 18338      CHN      Asia    China 2020-01-25       1401.0      483.0
# 18339      CHN      Asia    China 2020-01-26       2067.0      666.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 18335                 NaN          17.0         NaN                  NaN  ...
# 18336                 NaN          18.0         1.0                  NaN  ...
# 18337                 NaN          26.0         8.0                  NaN  ...
# 18338                 NaN          42.0        16.0                  NaN  ...
# 18339                 NaN          56.0        14.0                  NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 18335              0.7                261.899                 9.74
# 18336              0.7                261.899                 9.74
# 18337              0.7                261.899                 9.74
# 18338              0.7                261.899                 9.74
# 18339              0.7                261.899                 9.74
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 18335             1.9          48.4                     NaN
# 18336             1.9          48.4                     NaN
# 18337             1.9          48.4                     NaN
# 18338             1.9          48.4                     NaN
# 18339             1.9          48.4                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 18335                        4.34            76.91                    0.761
# 18336                        4.34            76.91                    0.761
# 18337                        4.34            76.91                    0.761
# 18338                        4.34            76.91                    0.761
# 18339                        4.34            76.91                    0.761
#
#        excess_mortality
# 18335               NaN
# 18336               NaN
# 18337               NaN
# 18338               NaN
# 18339               NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# ### Create plots

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(20, 12))



ax1.plot(data['date'], data['new_cases'])
# Set title and labels for axes
ax1.set(xlabel="Date (YYYY-MM)", ylabel="New cases", title="New cases in " + country)
ax1.grid()
ax1.fill_between(data['date'], data['new_cases'], color=(185/255,206/255,255/255,255/255))
ax1.set_ylim(ax1.get_ylim())




ax2.plot(data['date'], data['new_deaths'], color='black')
# Set title and labels for axes
ax2.set(xlabel="Date (YYYY-MM)", ylabel="New cases and deaths", title="New deaths in "+country)
ax2.grid()
ax2.fill_between(data['date'], data['new_deaths'], color=(0/255,0/255,0/255,50/255))
ax2.set_ylim(ax2.get_ylim())




ax3.plot(data['date'], data['total_cases'])
# Set title and labels for axes
ax3.set(xlabel="Date (YYYY-MM)", ylabel="Cumulative cases", title="Cumulative cases in "+country)
ax3.grid()
ax3.fill_between(data['date'], data['total_cases'], color=(185/255,206/255,255/255,255/255))
ax3.set_ylim(ax3.get_ylim())




ax4.plot(data['date'], data['total_deaths'], color='black')
# Set title and labels for axes
ax4.set(xlabel="Date (YYYY-MM)", ylabel="Cumulative deaths", title="Cumulative deaths in "+country)
ax4.grid()
ax4.fill_between(data['date'], data['total_deaths'], color=(0/255,0/255,0/255,50/255))
ax4.set_ylim(ax4.get_ylim())

plt.show()
